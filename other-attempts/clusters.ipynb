# %%
import pandas as pd

reviews = pd.read_json('data/ys-reviews-with-categories.json')

restuarants = reviews.loc[reviews.category == "restaurant"]

sample: list[str] = restuarants.text.tolist()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation

import yake as yk

stop_words = stopwords.words("english")
keyword_extractor = yk.KeywordExtractor(n=3,top=10000)
filtered_words = []

# def key_ngram_per_sentence (review_text) -> list[str]:
#     sentences = sent_tokenize(review_text)
#     key_ngrams = []
#     for sentence in sentences:
#         keywords = keyword_extractor.extract_keywords(removed_stopwords(sentence))
#         if len(keywords) > 0: key_ngrams.append(keywords[0][0])
#     return key_ngrams    
    
# def key_ngram (review_text) -> list[str]:
#     key_ngrams = []
#     keywords = keyword_extractor.extract_keywords(removed_stopwords(review_text))
#     if len(keywords) > 0: key_ngrams.append(keywords[0][0])
#     return key_ngrams    
    
def removed_stopwords(text: str) -> str:
    # make lower case and remove all punctuations
    text = text.lower().translate(str.maketrans('', '', punctuation))
    tokens = word_tokenize(text)
    # filter stopwords    
    filtered = [word for word in tokens if word not in stop_words]
    filtered = [word for word in tokens if word not in filtered_words]
    return ' '.join(filtered)


corpus = "\n".join(sample)
corpus = removed_stopwords(corpus)

extractions = keyword_extractor.extract_keywords(corpus)

with open('keywords.csv', 'w') as outfile:
    outfile.write(pd.DataFrame(extractions).to_csv(index=False))

# keywords = list(set([extraction[0] for extraction in extractions]))

# keywords

# %%
keywords_df = pd.read_csv('keywords.csv')
keywords = keywords_df[0:1000][keywords_df.columns[0]].tolist()
keywords
# Out:
# ['food service food',
#  'food food service',
#  'service food food',
#  'service food service',
#  'food customer service',
#  'friendly staff food',
#  'friendly service food',
#  'fast service food',
#  'food fast service',
#  'food friendly service',
#  'food service service',
#  'food excellent service',
#  'nice place food',
#  'customer service food',
#  'food friendly staff',
#  'place service food',
#  'place food service',
#  'food excellent food',
#  'service food nice',
#  'service excellent food',
#  'love love love',
#  'food nice place',
#  'excellent food food',
#  'food delicious food',
#  'service friendly staff',
#  'service delicious food',
#  'service awesome food',
#  'service service food',
#  'excellent food service',
#  'food service',
#  'service food love',
#  'food service love',
#  'food service prices',
#  'restaurant food service',
#  'food place service',
#  'food food',
#  'service food',
#  'place food place',
#  'food nice service',
#  'excellent service food',
#  'delicious food service',
#  'food service fast',
#  'food food friendly',
#  'staff food food',
#  'excellent customer service',
#  'fresh food service',
#  'place food nice',
#  'fast food places',
#  'food food nice',
#  'food service clean',
#  'awesome food service',
#  'service food prices',
#  'food quick service',
#  'back food food',
#  'service fast service',
#  'place customer service',
#  'fast friendly service',
#  'time food service',
#  'food prices food',
#  'food food price',
#  'prices food food',
#  'friendly staff service',
#  'service customer service',
#  'service tasty food',
#  'food drinks service',
#  'people food service',
#  'friendly customer service',
#  'place service place',
#  'staff delicious food',
#  'service excellent service',
#  'food nice people',
#  'place excellent food',
#  'friendly service place',
#  'place friendly service',
#  'food place love',
#  'foods food fast',
#  'food fast food',
#  'fast food food',
#  'customer service',
#  'service food friendly',
#  'staff food service',
#  'service food staff',
#  'food service awesome',
#  'people food food',
#  'wait food food',
#  'service nice place',
#  'food service nice',
#  'nice services foods',
#  'nice service food',
#  'nice food service',
#  'delicious service food',
#  'food service delicious',
#  'clean place food',
#  'fast food restaurant',
#  'friendly place food',
#  'place food friendly',
#  'nice people food',
#  'food fantastic food',
#  'awesome food place',
#  'meal food service',
#  'friendly service love',
#  'awesome food food',
#  'food food awesome',
#  'favorite place food',
#  'place nice food',
#  'service quality food',
#  'place delicious food',
#  'yummy food service',
#  'customer service service',
#  'tasty food service',
#  'delicious food',
#  'nice staff food',
#  'food nice staff',
#  'back food place',
#  'price food service',
#  'service prices food',
#  'price service food',
#  'food service pizza',
#  'pizza food service',
#  'pizza service food',
#  'service bad service',
#  'quick service food',
#  'food experience food',
#  'place food',
#  'food atmosphere food',
#  'food',
#  'food quality food',
#  'food thai food',
#  'friendly service nice',
#  'chicken food service',
#  'service breakfast food',
#  'food tasty food',
#  'service love love',
#  'delicious mexican food',
#  'price place food',
#  'real food food',
#  'fast service place',
#  'times excellent food',
#  'excellent food excellent',
#  'fast food service',
#  'sushi foods food',
#  'food food sushi',
#  'slow service food',
#  'food slow service',
#  'drinks service food',
#  'service food drinks',
#  'chicken food place',
#  'place nice staff',
#  'wait service food',
#  'mexican food service',
#  'food food pretty',
#  'food service fun',
#  'friendly fast service',
#  'eat service food',
#  'customer service love',
#  'food love love',
#  'cold food food',
#  'nice service service',
#  'service food taco',
#  'place food fast',
#  'service food clean',
#  'place food drinks',
#  'place people food',
#  'mexican food place',
#  'food food selection',
#  'service food ordered',
#  'staff excellent food',
#  'food awesome service',
#  'korean food food',
#  'food fun food',
#  'place fresh food',
#  'fresh food place',
#  'food staff love',
#  'food friendly wait',
#  'loved food food',
#  'place yummy food',
#  'nice time food',
#  'delicious food time',
#  'back food customer',
#  'delicious food excellent',
#  'bad customer service',
#  'food service reasonable',
#  'nice place love',
#  'food clean place',
#  'food places clean',
#  'nice customer service',
#  'food place',
#  'friendly service delicious',
#  'friendly service',
#  'delicious food love',
#  'place food awesome',
#  'awesome place food',
#  'place awesome food',
#  'fast service friendly',
#  'eating food food',
#  'eat delicious food',
#  'excellent food',
#  'place food location',
#  'menu place food',
#  'service food atmosphere',
#  'atmosphere service food',
#  'friendly staff place',
#  'place friendly staff',
#  'place nice place',
#  'food clean friendly',
#  'order food staff',
#  'nice fresh food',
#  'food bad service',
#  'service bad food',
#  'bad service food',
#  'service food long',
#  'service food quality',
#  'delicious fresh food',
#  'awesome food friendly',
#  'friendly employees food',
#  'food food items',
#  'food service coffee',
#  'lunch food service',
#  'service original food',
#  'food choices food',
#  'bar food service',
#  'friendly nice place',
#  'nice friendly place',
#  'food waitress food',
#  'delicious food clean',
#  'fast food',
#  'food service translated',
#  'restaurant place service',
#  'food nice friendly',
#  'service food beer',
#  'food service beer',
#  'food beer service',
#  'place food experience',
#  'service food tastes',
#  'cheese food service',
#  'atmosphere place food',
#  'excellent service service',
#  'pizza excellent food',
#  'nice place nice',
#  'food service family',
#  'prices friendly staff',
#  'fast service service',
#  'friendly service prices',
#  'food dirty food',
#  'thai food place',
#  'food prices love',
#  'service drinks service',
#  'super fast service',
#  'food restaurant love',
#  'delicious food nice',
#  'nice delicious food',
#  'food place original',
#  'delicious food delicious',
#  'eat service service',
#  'portions food service',
#  'breakfast service food',
#  'clean customer service',
#  'friendly staff',
#  'extremely food food',
#  'cold food service',
#  'excellent service place',
#  'love food chicken',
#  'fast service prices',
#  'food nice atmosphere',
#  'authentic mexican food',
#  'back delicious food',
#  'chinese food food',
#  'food highly recommend',
#  'fast service',
#  'italian food service',
#  'service place people',
#  'clean restaurant food',
#  'comida food food',
#  'friendly price food',
#  'friendly food price',
#  'food prices friendly',
#  'food selection service',
#  'staff prices food',
#  'customer service delicious',
#  'food staff restaurant',
#  'wait time food',
#  'service wonderful food',
#  'wonderful food service',
#  'google delicious food',
#  'fun service food',
#  'friendly service fast',
#  'food service highly',
#  'delicious food translated',
#  'food small place',
#  'food place small',
#  'eat fast food',
#  'food food sat',
#  'super friendly staff',
#  'nice restaurant food',
#  'food portions friendly',
#  'food nice pizza',
#  'delicious excellent service',
#  'pizza delicious food',
#  'food missing food',
#  'food shakes food',
#  'nice place',
#  'service yummy food',
#  'food nice',
#  'food consistently food',
#  'foods food fire',
#  'food fire food',
#  'service clean place',
#  'clean place service',
#  'food american food',
#  'american food food',
#  'unique food food',
#  'food service open',
#  'nice place customer',
#  'food kind service',
#  'quick service friendly',
#  'fantastic service food',
#  'fantastic food service',
#  'food fantastic service',
#  'indian food food',
#  'mexican food restaurant',
#  'food wonderful place',
#  'disappointed service food',
#  'food decent service',
#  'decent service food',
#  'food love taco',
#  'excellent food friendly',
#  'staff food excellent',
#  'excellent food staff',
#  'food food arrived',
#  'opened food food',
#  'staff food',
#  'fresh hot food',
#  'food friendly fast',
#  'food fast friendly',
#  'fast food friendly',
#  'bread food services',
#  'friendly service staff',
#  'review food service',
#  'comfort food food',
#  'expensive food service',
#  'rush food food',
#  'favorite place service',
#  'service food wrong',
#  'awesome customer service',
#  'dishes food service',
#  'friendly service awesome',
#  'parking service food',
#  'food friendly people',
#  'friendly people food',
#  'drink food staff',
#  'staff people food',
#  'service service coffee',
#  'location friendly service',
#  'places clean place',
#  'service service tasty',
#  'nice excellent food',
#  'location food love',
#  'friendly staff love',
#  'delicious excellent food',
#  'school food food',
#  'family friendly place',
#  'service nice friendly',
#  'food fast delicious',
#  'fast delicious food',
#  'food food poopie',
#  'crewdelicious food food',
#  'service experience place',
#  'food soooo food',
#  'sandwiches food service',
#  'food drinks nice',
#  'people food nice',
#  'service',
#  'delicious food drinks',
#  'horrible customer service',
#  'people delicious food',
#  'mexican food nice',
#  'food service size',
#  'clean place friendly',
#  'wait delicious food',
#  'service mcdonalds food',
#  'absolutely food service',
#  'terrible food service',
#  'burgers nice food',
#  'greek food food',
#  'today service food',
#  'food love',
#  'place expensive food',
#  'waiting food service',
#  'food kind staff',
#  'clean friendly food',
#  'coming back food',
#  'food attentive service',
#  'attentive service food',
#  'cool place food',
#  'restaurant service love',
#  'service delicious nice',
#  'food reasonable prices',
#  'worst customer service',
#  'delicious food fresh',
#  'time coffee food',
#  'staff food awesome',
#  'clean friendly staff',
#  'food dont order',
#  'food food specially',
#  'nice clean place',
#  'food friendly',
#  'friendly food make',
#  'customer service excellent',
#  'excellent service',
#  'place huge food',
#  'time tasty food',
#  'chicken restaurant food',
#  'staff food location',
#  'menu food staff',
#  'nice staff place',
#  'place order delicious',
#  'customer service fast',
#  'quality food love',
#  'food allergies food',
#  'delicious clean food',
#  'delicious awesome place',
#  'food long wait',
#  'poor service food',
#  'food poor service',
#  'google food original',
#  'bar food love',
#  'chinese food service',
#  'return food service',
#  'place service sushi',
#  'service food fair',
#  'fries food friendly',
#  'excellent food prices',
#  'prices excellent food',
#  'food staff fries',
#  'job food service',
#  'excellent service excellent',
#  'easy service food',
#  'offer food service',
#  'delicious food menu',
#  'food music love',
#  'mexican food',
#  'comida service food',
#  'consistently delicious food',
#  'hot food love',
#  'slow service service',
#  'fast food pizza',
#  'restaurant friendly service',
#  'love chinese food',
#  'patio food service',
#  'environment service food',
#  'place service breakfasts',
#  'excellent service love',
#  'time friends food',
#  'staff quick service',
#  'restaurant people food',
#  'food friendly atmosphere',
#  'vibe food service',
#  'delicious italian food',
#  'fast service love',
#  'food delivery service',
#  'high quality food',
#  'food excellent customer',
#  'attentive staff food',
#  'service service loved',
#  'delicious food ive',
#  'service cafe food',
#  'food service tasting',
#  'service food chef',
#  'chinese food restaurant',
#  'customer service friendly',
#  'friendly service customer',
#  'professional service food',
#  'fast food chicken',
#  'food original muy',
#  'nice restaurant service',
#  'fresh food prices',
#  'food coffee staff',
#  'portions friendly service',
#  'fair food place',
#  'floor food service',
#  'customer service awesome',
#  'absolutely delicious food',
#  'awesome food',
#  'friendly service happy',
#  'experience nice food',
#  'staff tasty food',
#  'food service early',
#  'cheap food place',
#  'nice atmosphere food',
#  'experience delicious food',
#  'pleasant place food',
#  'efficient service food',
#  'food service ambiance',
#  'delicious food atmosphere',
#  'service overpriced food',
#  'yum service food',
#  'service fantastic service',
#  'courteous service food',
#  'clean prices food',
#  'food mediocre service',
#  'service mediocre food',
#  'friendly beer food',
#  'lettuce food service',
#  'food beer staff',
#  'hot food order',
#  'place',
#  'toast food service',
#  'nice quality food',
#  'food restaurant clean',
#  'friendly staff clean',
#  'delicious quality food',
#  'quality food delicious',
#  'pasta food service',
#  'service fun place',
#  'food decent prices',
#  'fast food excellent',
#  'excellent food fast',
#  'disgusting food service',
#  'food cocktails service',
#  'friendly service excellent',
#  'excellent friendly service',
#  'excellent service friendly',
#  'coffee delicious food',
#  'service excellent staff',
#  'delicious food lunch',
#  'lunch delicious food',
#  'wow food service',
#  'food prices awesome',
#  'bar food nice',
#  'tasty food nice',
#  'delicious food original',
#  'food delicious original',
#  'food prices',
#  'food fun times',
#  'delicious food tasty',
#  'food quick staff',
#  'excellent food people',
#  'food staff family',
#  'awesome food pizza',
#  'pizzas awesome food',
#  'service service',
#  'fast food fast',
#  'food solid service',
#  'super nice staff',
#  'staff fast service',
#  'sushi staff food',
#  'food chicken tacos',
#  'eat excellent food',
#  'price nice place',
#  'excellent food burgers',
#  'nice food translated',
#  'quality mexican food',
#  'generous food service',
#  'friendly environment food',
#  'food service typical',
#  'place nice restaurant',
#  'favorite pizza place',
#  'friendly people service',
#  'pizza nice place',
#  'nice beer food',
#  'service wait staff',
#  'fast food burger',
#  'delicious food hot',
#  'hot delicious food',
#  'food superb service',
#  'burger service friendly',
#  'burgers friendly service',
#  'healthier food service',
#  'food wonderful people',
#  'staff outstanding food',
#  'customer service experience',
#  'club food service',
#  'hour delicious food',
#  'eats drinks food',
#  'excellent service delicious',
#  'prompt service foods',
#  'food alright service',
#  'food service treated',
#  'excellent fresh food',
#  'tiramisu food service',
#  'steady service food',
#  'happy food friendly',
#  'area delicious food',
#  'salads delicious food',
#  'italian food place',
#  'fast service nice',
#  'nice fast service',
#  'pretty nice place',
#  'recommend excellent service',
#  'things food friendly',
#  'fast service delicious',
#  'disappointed place service',
#  'service food woodstock',
#  'service food butdontliveawaytheywontdeliveroutome',
#  'strength food service',
#  'food reasonble service',
#  'fresh food fast',
#  'dining food prices',
#  'service eating place',
#  'time food kind',
#  'spot delicious food',
#  'food service hole',
#  'service mediterranean food',
#  'service food god',
#  'food home love',
#  'home love food',
#  'fresh food',
#  'nice people service',
#  'time awesome place',
#  'service pricy food',
#  'win food service',
#  'service delicious drinks',
#  'service people delicious',
#  'korean food place',
#  'order tacos service',
#  'service sucked food',
#  'clean excellent food',
#  'service terrible service',
#  'place service',
#  'sister food service',
#  'food lovely place',
#  'lovely place food',
#  'trip place food',
#  'friendly place fast',
#  'service love',
#  'back food',
#  'food friendly servers',
#  'expensive place service',
#  'experience pizza food',
#  'food fast clean',
#  'food clean fast',
#  'negative food service',
#  'food service undercooked',
#  'delicious food breakfast',
#  'food staff',
#  'friendly clean service',
#  'atmosphere friendly staff',
#  'awesome excellent food',
#  'food excellent awesome',
#  'food service specialty',
#  'summer food service',
#  'food nice employees',
#  'service highly recommend',
#  'food nice cold',
#  'time friendly staff',
#  'scrumptious food service',
#  'back fast service',
#  'food service slowest',
#  'place burgers friendly',
#  'friendly place burger',
#  'food small nice',
#  'mexican food clean',
#  'service reasonable prices',
#  'awesome food fast',
#  'fast food awesome',
#  'rude customer service',
#  'food super prices',
#  'customer service drive',
#  'taste customer service',
#  'fresh food fresh',
#  'halal food service',
#  'quality restaurant food',
#  'restaurant food quality',
#  'lunch time service',
#  'food speedy service',
#  'speedy service food',
#  'food wonderful staff',
#  'service food luckily',
#  'food luckily service',
#  'food nice ambiance',
#  'mexican food staff',
#  'bad service bad',
#  'place food low',
#  'awesome food drinks',
#  'food awesome drinks',
#  'awesome drinks food',
#  'customer service pizza',
#  'pizza customer service',
#  'original food prices',
#  'price food original',
#  'love love',
#  'place horrible service',
#  'order food',
#  'google food prices',
#  'fresh food taco',
#  'prices tasty foods',
#  'nice place fast',
#  'excellent service original',
#  'food soso service',
#  'google excellent service',
#  'lineprep food place',
#  'place wgreat food',
#  'soul food place',
#  'eating place place',
#  'friendly staff tasty',
#  'disrespect food service',
#  'delicious food server',
#  'fast service coffee',
#  'nice place drinks',
#  'place nice people',
#  'nice people place',
#  'people nice place',
#  'service smelly food',
#  'complex service food',
#  'delicious indian food',
#  'wait nice place',
#  'clean fresh food',
#  'everyday food place',
#  'place full service',
#  'flavor delicious food',
#  'favorite fast food',
#  'sacramento food pizza',
#  'food nice selection',
#  'recommend excellent food',
#  'beer prices food',
#  'favorite burger place',
#  'prices food tastes',
#  'quality food',
#  'sandwich delicious food',
#  'wonderful food nice',
#  'fast food fries',
#  'visit food nice',
#  'friendly yummy food',
#  'yummy food friendly',
#  'awesome food fresh',
#  'food fair price',
#  'staff yummy food',
#  'made food customer',
#  'excellent service prices',
#  'clean friendly place',
#  'delicious wonderful food',
#  'delicious food wonderful',
#  'lunch food customer',
#  'friendly food',
#  'mexican food delicious',
#  'mexican delicious food',
#  'excellent restaurant service',
#  'delicious food fun',
#  'taco food ordered',
#  'fast food ive',
#  'excellent service pizza',
#  'food salads prices',
#  'tasty foods customer',
#  'food greatest place',
#  'price food quick',
#  'delicious food highly',
#  'restaurant salads food',
#  'price fast service',
#  'food awsome place',
#  'beer service love',
#  'excellent food atmosphere',
#  'place delicious fresh',
#  'nice wait staff',
#  'options delicious food',
#  'fast service restaurant',
#  'place food confusing',
#  'fast service pizza',
#  'pizza fast service',
#  'time coffee place',
#  'staff awesome place',
#  'awesome place staff',
#  'sushi restaurant food',
#  'clean food ordered',
#  'highly recommend food',
#  'table food fast',
#  'foods food',
#  'mexican food ive',
#  'table service friendly',
#  'time food',
#  'awesome food clean',
#  'awesome awesome place',
#  'mcdonalds food love',
#  'prices food pretty',
#  'foods decent staffs',
#  'decent food staff',
#  'chicken pizza place',
#  'chicken food beer',
#  'worst fast food',
#  'quick service love',
#  'excellent food quality',
#  'service awesome atmosphere',
#  'excellent food didnt',
#  'delicious yummy food',
#  'food wonderful atmosphere',
#  'service excellent customer',
#  'breakfast food prices',
#  'awesome food awesome',
#  'delicious clean place',
#  'food fast',
#  'chicken service excellent',
#  'chicken excellent service',
#  'friendly owners food',
#  'order friendly staff',
#  'friendly staff order',
#  'fun atmosphere food',
#  'pretty fast service',
#  'portions friendly staff',
#  'food location ordered',
#  'employees food prices',
#  'wrong order food',
#  'friendly service quality',
#  'tasty food excellent',
#  'ordered nice place',
#  'sauce food price',
#  'service super friendly',
#  'super friendly service',
#  'dishes food staff',
#  'location awesome food',
#  'fast service customer',
#  'food excellent',
#  'wife loves food',
#  'nice place awesome',
#  'coffee friendly service',
#  'service coffee friendly',
#  'average service service',
#  'busy fast service',
#  'delicious food cooked',
#  'staff coffee service',
#  'people super food',
#  'sacramento excellent food',
#  'bar friendly service',
#  'love thai food',
#  'customer service drinks',
#  'fresh pizza service',
#  'location friendly staff',
#  'place makes delicious',
#  'people customer service',
#  'coffee food drinks',
#  'people coffee food',
#  'nice place menu',
#  'tasty food',
#  'service nice atmosphere',
#  'food friendly helpful',
#  'time chinese food',
#  'eat customer service',
#  'nice clean friendly',
#  'drinks tasty food',
#  'staff food reasonable',
#  'food tastes excellent',
#  'taste excellent food',
#  'sacramento friendly service',
#  'mexican food original',
#  'tasty mexican food',
#  'yum food prices',
#  'friendly service translated',
#  'food original buena',
#  'called fast food',
#  'nice staff friendly',
#  'friendly staff nice',
#  'perfect food delicious',
#  'food happy customer',
#  'fast efficient service',
#  'fast hot food',
#  'fast food hot',
#  'favorite place nice',
#  'friendly staff delicious',
#  'delicious friendly staff',
#  'recommend awesome food',
#  'service pricey place',
#  'food fast drive',
#  'service clean restaurant',
#  'bad service delicious',
#  'cold food customer',
#  'service friendly',
#  'cars time food',
#  'back nice people',
#  'excellent fast service',
#  'excellent service fast',
#  'family place love',
#  'cool delicious food',
#  'prices service awesome',
#  'fresh food lots',
#  'staff terrible food',
#  'friendly service salad',
#  'order quick service',
#  'run place service',
#  'friendly service family',
#  'food tasted delicious',
#  'hour wait food',
#  'service awesome pizza',
#  'service love coming',
#  'back food decent',
#  'service awesome area',
#  'helpful delicious food',
#  'long wait time',
#  'place real place',
#  'service place',
#  'atmosphere awesome food',
#  'delicious food huge',
#  'food restaurant',
#  'favorite food recommend',
#  'food friendly attentive',
#  'people fast service',
#  'customer service fantastic',
#  'excellent breakfast food',
#  'food excellent breakfast',
#  'fast food pretty',
#  'food pretty fast',
#  'delicious nice staff',
#  'star excellent food',
#  'fast service burgers',
#  'nice atmosphere place',
#  'hot fresh food',
#  'food nice seating',
#  'friendly food thai',
#  'busy fast food',
#  'breakfast fast food',
#  'favorite restaurant service',
#  'friends food drinks',
#  'pizza place taco',
#  'reasonable prices service',
#  'burgers people service',
#  'food quality makes',
#  'food awesome made',
#  'wait burgers service',
#  'prices yummy food',
#  'customer service dont',
#  'excellent place excellent',
#  'back service tasty',
#  'bad food location',
#  'food fresh salad',
#  'yummy excellent service',
#  'awesome place translated',
#  'love flavorful food',
#  'online food love',
#  'delicious priced food',
#  'mexican food chicken',
#  'back place ive',
#  'restaurant food',
#  'tacos excellent service',
#  'customer service location',
#  'service service dependably',
#  'fresh fast service',
#  'excellent place fast',
#  'hot food clean',
#  'cold drinks food',
#  'location bar food',
#  'service original muy',
#  'servers excellent food',
#  'burgers love love',
#  'google bad service',
#  'service clean excellent',
#  'salad friendly place',
#  'favorite place',
#  'staff family place',
#  'food nice variety',
#  'excellent flavor food',
#  'food excellent flavor',
#  'services lovely place',
#  'chinese food friendly',
#  'food awesome beer',
#  'food delicious desserts',
#  'return food staff',
#  'thai food nice',
#  'delicious food variety',
#  'decent food prices',
#  'service atmosphere prices',
#  'tacos service drinks',
#  'delicious thai food',
#  'delicious food thai',
#  'fast food chain',
#  'clean fast service',
#  'decent pizza food',
#  'money back food',
#  'food drinks servers',
#  'fantastic service love',
#  'yummy food chicken',
#  'years excellent food',
#  'clean food',
#  'people clean service',
#  'friendly staff prices',
#  'home time place',
#  'order slow service',
#  'food expensive price',
#  'friendly service slow',
#  'service prices bad',
#  'prices bad service',
#  'order times people',
#  'excellent food highly',
#  'customer service sucks',
#  'food big portions',
#  'awesome service fast',
#  'pizzas friendly staff',
#  'back food authentic',
#  'food environment friendly',
#  'delicious food music',
#  'friendly service wonderful',
#  'service pizza quality',
#  'place love',
#  'mexican fast food',
#  'place ordered chicken',
#  'friendly staff quick',
#  'awesome place customer',
#  'table food quality',
#  'service prices lots',
#  'favorites hot food',
#  'staff food vibe',
#  'nice quick place',
#  'nice family place',
#  'food portions clean']

# %%
[ngram for ngram in keywords if 'food' not in ngram.split(' ')]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering

# Sample trigrams
trigrams = keywords

# Convert trigrams to TF-IDF vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(trigrams)

# Calculate cosine similarity matrix
cosine_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Perform hierarchical clustering
n_clusters = 50  # You can adjust the number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters, metric='cosine', linkage='average')
cluster_labels = clustering.fit_predict(cosine_sim_matrix)

# Assign trigrams to clusters
trigram_clusters = {}
for trigram, label in zip(trigrams, cluster_labels):
    if label not in trigram_clusters:
        trigram_clusters[label] = []
    trigram_clusters[label].append(trigram)

# Print the trigram clusters
for label, cluster in trigram_clusters.items():
    if len(cluster) > 1 : print(f'Cluster {label + 1}: {cluster}')
# Out:
# Cluster 10: ['food service food', 'food food service', 'service food food', 'service food service', 'food service service', 'service service food', 'food service', 'service food', 'food quick service', 'service tasty food', 'meal food service', 'yummy food service', 'tasty food service', 'service bad service', 'quick service food', 'service breakfast food', 'slow service food', 'food slow service', 'eat service food', 'service food taco', 'service food ordered', 'food service reasonable', 'food bad service', 'service bad food', 'bad service food', 'service food long', 'food service coffee', 'lunch food service', 'bar food service', 'food service translated', 'service food beer', 'food service beer', 'food beer service', 'service food tastes', 'cheese food service', 'food service family', 'eat service service', 'portions food service', 'breakfast service food', 'italian food service', 'food selection service', 'service wonderful food', 'wonderful food service', 'food service highly', 'service yummy food', 'food service open', 'food kind service', 'fantastic service food', 'fantastic food service', 'food fantastic service', 'disappointed service food', 'food decent service', 'decent service food', 'review food service', 'expensive food service', 'service food wrong', 'dishes food service', 'parking service food', 'service service coffee', 'service service tasty', 'sandwiches food service', 'service', 'food service size', 'service mcdonalds food', 'absolutely food service', 'terrible food service', 'today service food', 'waiting food service', 'food attentive service', 'attentive service food', 'poor service food', 'food poor service', 'return food service', 'service food fair', 'job food service', 'easy service food', 'offer food service', 'comida service food', 'slow service service', 'patio food service', 'environment service food', 'vibe food service', 'food delivery service', 'service service loved', 'service cafe food', 'food service tasting', 'service food chef', 'professional service food', 'floor food service', 'food service early', 'efficient service food', 'food service ambiance', 'service overpriced food', 'yum service food', 'service fantastic service', 'courteous service food', 'food mediocre service', 'service mediocre food', 'lettuce food service', 'toast food service', 'pasta food service', 'disgusting food service', 'food cocktails service', 'wow food service', 'service service', 'food solid service', 'generous food service', 'food service typical', 'food superb service', 'healthier food service', 'club food service', 'food alright service', 'food service treated', 'tiramisu food service', '
# Cluster 25: ['fresh food service', 'fresh hot food', 'fresh food', 'fresh food fresh', 'fresh food taco', 'fresh pizza service', 'fresh food lots', 'hot fresh food', 'food fresh salad']
# Cluster 9: ['food service clean', 'clean place food', 'service food clean', 'food clean place', 'food places clean', 'food clean friendly', 'delicious food clean', 'clean restaurant food', 'service clean place', 'clean place service', 'places clean place', 'clean place friendly', 'clean friendly food', 'nice clean place', 'delicious clean food', 'clean prices food', 'food restaurant clean', 'friendly clean service', 'mexican food clean', 'clean fresh food', 'clean friendly place', 'clean food ordered', 'delicious clean place', 'nice clean friendly', 'service clean restaurant', 'hot food clean', 'clean food', 'food portions clean']
# Cluster 20: ['back food food', 'coming back food', 'back food', 'back food decent', 'money back food', 'back food authentic']
# Cluster 28: ['time food service', 'time coffee food', 'time friends food', 'time food kind', 'lunch time service', 'time food', 'time chinese food', 'cars time food']
# Cluster 11: ['food food price', 'price food service', 'price service food', 'price food original', 'food fair price', 'price food quick', 'sauce food price', 'food expensive price']
# Cluster 34: ['food drinks service', 'drinks service food', 'service food drinks', 'service drinks service', 'delicious food drinks', 'eats drinks food', 'service delicious drinks', 'coffee food drinks', 'drinks tasty food', 'friends food drinks', 'cold drinks food', 'tacos service drinks', 'food drinks servers']
# Cluster 7: ['people food service', 'people food food', 'restaurant people food', 'food wonderful people', 'people super food', 'people coffee food', 'burgers people service', 'people clean service']
# Cluster 47: ['food place love', 'nice place love', 'family place love', 'place love']
# Cluster 1: ['wait food food', 'wait service food', 'wait time food', 'food long wait', 'hour wait food', 'long wait time', 'wait burgers service']
# Cluster 13: ['service quality food', 'food quality food', 'service food quality', 'high quality food', 'quality mexican food', 'quality food', 'food quality makes', 'table food quality']
# Cluster 5: ['nice staff food', 'food nice staff', 'place nice staff', 'nice staff place', 'super nice staff', 'nice wait staff', 'nice staff friendly', 'friendly staff nice', 'staff family place']
# Cluster 35: ['food service pizza', 'pizza food service', 'pizza service food', 'experience pizza food', 'sacramento food pizza', 'decent pizza food', 'service pizza quality']
# Cluster 38: ['food atmosphere food', 'service food atmosphere', 'atmosphere service food', 'food wonderful atmosphere', 'fun atmosphere food']
# Cluster 17: ['chicken food service', 'food chicken tacos', 'chicken food beer', 'yummy food chicken']
# Cluster 37: ['food tasty food', 'time tasty food', 'tasty food', 'tasty mexican food']
# Cluster 32: ['sushi foods food', 'foods food fire', 'foods food']
# Cluster 42: ['mexican food service', 'authentic mexican food', 'mexican food', 'mexican food ive', 'mexican food original', 'mexican food chicken']
# Cluster 23: ['food service fun', 'food fun food', 'fun service food', 'food fun times']
# Cluster 49: ['service original food', 'google food original', 'food original muy', 'food original buena', 'service original muy']
# Cluster 2: ['food highly recommend', 'service highly recommend', 'highly recommend food', 'favorite food recommend']
# Cluster 48: ['food dont order', 'order food', 'wrong order food']
# Cluster 33: ['hot food order', 'favorites hot food']
# Cluster 41: ['favorite pizza place', 'chicken pizza place', 'pizza place taco']
# Cluster 27: ['order tacos service', 'order slow service']
# Cluster 40: ['time coffee place', 'home time place']
# Cluster 16: ['food location ordered', 'bad food location', 'location bar food']
